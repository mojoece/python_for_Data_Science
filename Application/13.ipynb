# %% [markdown]
# map and filter
# - map is a builtin function in python that helps us to create a iterator automatically and then output the values based on that

# %%
def times2(num):
    return num*2

# %%
times2(5)
# Out:
# 10

# %%
seq = [1, 2, 3, 4, 5]

# %%
map(times2, seq)

# %%
list(map(times2, seq))
# Out:
# [2, 4, 6, 8, 10]

# %%
# In this map, we dont want to write the separate big function for using it so, what we do instead is that we use lambda functions for this

# %% [markdown]
# lambda function or anonymous function
# - Here, we don't want to define an entire function rather things become much simpler and with the information that we need.

# %%
test = lambda var: var*2

# %%
test(3)
# Out:
# 6

# %%
list(map(lambda var: var*3, seq))
# Out:
# [3, 6, 9, 12, 15]

# %% [markdown]
# Filter Function
# - Similar structure like Map but instead of mapping a function to every element in a sequence, we will filter out elements from a sequence
# - Uses some sort of function to return a boolean value then it gets passed into an iterable object and when you call a list on it, it only returns the values where the statement happened to be true.

# %%
list(filter(lambda num: num%2==0, seq))
# Out:
# [2, 4]

# %% [markdown]
# Methods
# - Essential just calls we can make off an object that will affect the object or return a result in some manner

# %%
s = 'Hello my name is Mojo'

# %%
s.lower()   # Converts all chars to lowercase
# Out:
# 'hello my name is mojo'

# %%
s.upper()   # Converts all chars to uppercase
# Out:
# 'HELLO MY NAME IS MOJO'

# %%
s.split()   # Splits an string on whitespace of that string into a list of multiple strings
# The split based on whitespace is default else we can specify on what basis we want to split such as in next code cell
# Out:
# ['Hello', 'my', 'name', 'is', 'Mojo']

# %%
s.split('o')
# Out:
# ['Hell', ' my name is M', 'j', '']

# %%
tweet = 'Go Go! Make the best use of resources....      #Sports'

# %%
tweet.split()
# Out:
# ['Go', 'Go!', 'Make', 'the', 'best', 'use', 'of', 'resources....', '#Sports']

# %%
tweet.split('#')[1]    # As, the .split() returns a list so we can apply all the list based functions in it.
# Out:
# 'Sports'

# %%
d1 = {
    'k1' : 1,
    'k2' : 2
}

# %%
d1
# Out:
# {'k1': 1, 'k2': 2}

# %%
d1.keys()    # returns the keys present in the dictionary
# Out:
# dict_keys(['k1', 'k2'])

# %%
d1.items()    # Returns keys and values
# Out:
# dict_items([('k1', 1), ('k2', 2)])

# %%
d1.values()   # Returns the values in a dictionary
# Out:
# dict_values([1, 2])

# %%
lst = [1, 2, 3, 4, 5]

# %%
lst.pop()    # Remove and return item at index (default last).
# Out:
# 5

# %%
lst
# Out:
# [1, 2, 3, 4]

# %%
item = lst.pop()

# %%
lst
# Out:
# [1, 2, 3]

# %%
item
# Out:
# 4

# %%
lst
# Out:
# [1, 2, 3]

# %%
first = lst.pop(0)    # This pops the element present in first index and keeps everything same....We can mention the index we need to pop

# %%
lst
# Out:
# [2, 3]

# %%
lst.append('new item')

# %%
lst
# Out:
# [2, 3, 'new item']

# %%
# In Operator - To check if something is inside a list or not

# %%
'x' in [1, 2, 3, 4, 5]
# Out:
# False

# %%
'x' in [1, 2, 'x', 4, 6]
# Out:
# True
